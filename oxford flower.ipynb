# %% [markdown]
# <a href="https://colab.research.google.com/github/youssef2620/ASDC/blob/main/oxford%20flower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Importing Needed Libraries**

# %%
import os
import requests
import tarfile
import scipy
from scipy import io
import pandas as pd
from sklearn.model_selection import train_test_split
from PIL import Image

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

DataPath = '/content/drive/My Drive/data_final'
LabelsPath = os.path.join(DataPath, 'labels.csv')
if not os.path.exists(DataPath):
  os.mkdir(DataPath)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Downloading Dataset**

# %%
tgz_path = os.path.join(DataPath, '102flowers.tgz')
url = 'http://www.robots.ox.ac.uk/~vgg/data/flowers/102/102flowers.tgz'
r_image = requests.get(url)
with open(tgz_path, 'wb') as f:
  f.write(r_image.content)
tar = tarfile.open(tgz_path, 'r')
for item in tar:
  tar.extract(item, DataPath)

# %%
mat_path = os.path.join(DataPath, 'imagelabels.mat')
label_url = 'http://www.robots.ox.ac.uk/~vgg/data/flowers/102/imagelabels.mat'
r_label = requests.get(label_url)
with open(mat_path, 'wb') as f:
  f.write(r_label.content)

# %% [markdown]
# ## **Data Integration and Labeling**

# %%
# Load labels and create DataFrame
matdata = scipy.io.loadmat(mat_path)
labels = matdata['labels'][0]
images = ['image_{:05}.jpg'.format(i + 1) for i in range(len(labels))]
image_label_df = pd.DataFrame({'image': images, 'label': labels})

actual_labels = ["pink primrose", "hard-leaved pocket orchid", "canterbury bells", "sweet pea", "english marigold", "tiger lily", "moon orchid",
        "bird of paradise", "monkshood", "globe thistle", "snapdragon", "colt's foot", "king protea", "spear thistle", "yellow iris",
        "globe-flower", "purple coneflower", "peruvian lily", "balloon flower", "giant white arum lily", "fire lily", "pincushion flower", "fritillary",
        "red ginger", "grape hyacinth", "corn poppy", "prince of wales feathers", "stemless gentian", "artichoke", "sweet william", "carnation",
        "garden phlox", "love in the mist", "mexican aster", "alpine sea holly", "ruby-lipped cattleya", "cape flower", "great masterwort", "siam tulip",
        "lenten rose", "barbeton daisy", "daffodil", "sword lily", "poinsettia", "bolero deep blue", "wallflower", "marigold", "buttercup", "oxeye daisy",
        "common dandelion", "petunia", "wild pansy", "primula", "sunflower", "pelargonium", "bishop of llandaff", "gaura", "geranium", "orange dahlia",
        "pink-yellow dahlia?", "cautleya spicata", "japanese anemone", "black-eyed susan", "silverbush", "californian poppy", "osteospermum",
        "spring crocus", "bearded iris", "windflower", "tree poppy", "gazania", "azalea", "water lily", "rose", "thorn apple", "morning glory",
        "passion flower", "lotus", "toad lily", "anthurium", "frangipani", "clematis", "hibiscus", "columbine", "desert-rose", "tree mallow",
        "magnolia", "cyclamen", "watercress", "canna lily", "hippeastrum", "bee balm", "ball moss", "foxglove", "bougainvillea", "camellia", "mallow",
        "mexican petunia", "bromelia", "blanket flower", "trumpet creeper", "blackberry lily"]



# Add actual labels to the DataFrame
image_label_df['actual_label'] = [actual_labels[label - 1] for label in labels]

# Create a new DataFrame with the specified format
result_df = pd.DataFrame({
    'image': image_label_df['image'],
    'label': image_label_df['label'],
    'actual_label': image_label_df['actual_label']
})

# Save the new DataFrame as a CSV file
csv_path = os.path.join(DataPath, 'image_label_name.csv')
result_df.to_csv(csv_path, index=False)

# %% [markdown]
# ## **Splitting Dataset**

# %%
X_train_path = os.path.join(DataPath, 'X_train')
X_test_path = os.path.join(DataPath, 'X_test')
jpg_path = os.path.join(DataPath, 'jpg')
csv_path = os.path.join(DataPath, 'image_label_name.csv')

# %%
from shutil import copyfile

# Load labels from CSV
labels = pd.read_csv(csv_path)

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(labels['image'], labels['actual_label'], test_size=0.2, random_state=0)

# Create directories if they don't exist
if not os.path.exists(X_train_path):
    os.mkdir(X_train_path)
if not os.path.exists(X_test_path):
    os.mkdir(X_test_path)

# Copy images to the corresponding directories
for f in os.listdir(jpg_path):
    img_path = os.path.join(jpg_path, f)
    img = Image.open(img_path)
    if f in X_train.values:
        img.save(os.path.join(X_train_path, f))
    elif f in X_test.values:
        img.save(os.path.join(X_test_path, f))

# %%
# Loop through images in the training set
for f in os.listdir(X_train_path):
    # Find the index of the image in the DataFrame
    index = labels.index[labels['image'] == f].tolist()[0]

    # Get the category based on the actual label
    category = str(labels.at[index, 'actual_label']).replace('[', '').replace(']', '').replace("'", '')

    # Handle special cases
    if category == "colts foot":
        category = "colt's foot"

    # Create category path if it doesn't exist
    category_path = os.path.join(X_train_path, category)
    if not os.path.exists(category_path):
        os.makedirs(category_path)

    # Move the image to the corresponding category directory
    img_path = os.path.join(X_train_path, f)
    img = Image.open(img_path)
    img.save(os.path.join(category_path, f))

    # Remove the original image
    os.remove(img_path)

# %%
# Loop through images in the testing set
for f in os.listdir(X_test_path):
    # Find the index of the image in the DataFrame
    index = labels.index[labels['image'] == f].tolist()[0]

    # Get the category based on the actual label
    category = str(labels.at[index, 'actual_label']).replace('[', '').replace(']', '').replace("'", '')

    # Handle special cases
    if category == "colts foot":
        category = "colt's foot"

    # Create category path if it doesn't exist
    category_path = os.path.join(X_test_path, category)
    if not os.path.exists(category_path):
        os.makedirs(category_path)

    # Move the image to the corresponding category directory
    img_path = os.path.join(X_test_path, f)
    img = Image.open(img_path)
    img.save(os.path.join(category_path, f))

    # Remove the original image
    os.remove(img_path)

# %% [markdown]
# ## **Importing Needed Libraries for Training**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
num_classes = 102
batch_size = 64
img_size = 224
epochs = 30
num_train = 6551
num_val = 1638
label = ["pink primrose", "hard-leaved pocket orchid", "canterbury bells", "sweet pea", "english marigold", "tiger lily", "moon orchid",
        "bird of paradise", "monkshood", "globe thistle", "snapdragon", "colt's foot", "king protea", "spear thistle", "yellow iris",
        "globe-flower", "purple coneflower", "peruvian lily", "balloon flower", "giant white arum lily", "fire lily", "pincushion flower", "fritillary",
        "red ginger", "grape hyacinth", "corn poppy", "prince of wales feathers", "stemless gentian", "artichoke", "sweet william", "carnation",
        "garden phlox", "love in the mist", "mexican aster", "alpine sea holly", "ruby-lipped cattleya", "cape flower", "great masterwort", "siam tulip",
        "lenten rose", "barbeton daisy", "daffodil", "sword lily", "poinsettia", "bolero deep blue", "wallflower", "marigold", "buttercup", "oxeye daisy",
        "common dandelion", "petunia", "wild pansy", "primula", "sunflower", "pelargonium", "bishop of llandaff", "gaura", "geranium", "orange dahlia",
        "pink-yellow dahlia?", "cautleya spicata", "japanese anemone", "black-eyed susan", "silverbush", "californian poppy", "osteospermum",
        "spring crocus", "bearded iris", "windflower", "tree poppy", "gazania", "azalea", "water lily", "rose", "thorn apple", "morning glory",
        "passion flower", "lotus", "toad lily", "anthurium", "frangipani", "clematis", "hibiscus", "columbine", "desert-rose", "tree mallow",
        "magnolia", "cyclamen", "watercress", "canna lily", "hippeastrum", "bee balm", "ball moss", "foxglove", "bougainvillea", "camellia", "mallow",
        "mexican petunia", "bromelia", "blanket flower", "trumpet creeper", "blackberry lily"]

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=45,
    width_shift_range=.15,
    height_shift_range=.15,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.5,
    shear_range=0.2
    )

val_datagen = ImageDataGenerator(rescale=1.0/255)

train_gen = train_datagen.flow_from_directory(
    X_train_path,
    target_size=(img_size, img_size),
    color_mode='rgb',
    batch_size=batch_size,
#     classes=label,
    class_mode='categorical',
    shuffle=True
)

val_gen = val_datagen.flow_from_directory(
    X_test_path,
    target_size=(img_size, img_size),
    color_mode='rgb',
    batch_size=batch_size,
#     classes=label,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 6551 images belonging to 102 classes.
# Found 1638 images belonging to 102 classes.

# %% [markdown]
# # **Training using Transfer Learning**

# %%
from tensorflow.keras.applications import MobileNetV2

# Specify the input shape and create the MobileNetV2 base model
img_size = 224  # Adjust the image size based on your requirements
base_model = MobileNetV2(input_shape=(img_size, img_size, 3), alpha=0.5, include_top=False, weights='imagenet')

# Optional: Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(102, activation='softmax')(x)  #102 classes for classification

# Create the final model
model = Model(inputs=base_model.input, outputs=x)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print a summary of the model architecture
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.5_224_no_top.h5
# 3201480/3201480 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 112, 112, 16)         432       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 112, 112, 16)         64        ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 112, 112, 16)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 112, 112, 16)         144       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 16)         64        ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 112, 112, 16)         0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 112, 112, 8)          128       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 112, 112, 8)          32        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 112, 112, 48)         384       ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 112, 112, 48)         192       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 112, 112, 48)         0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 113, 113, 48)         0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 56, 56, 48)           432       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 56, 56, 48)           192       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 56, 56, 48)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 56, 56, 16)           768       ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 56, 56, 16)           64        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 56, 56, 96)           1536      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 56, 56, 96)           384       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 56, 56, 96)           0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 56, 56, 96)           864       ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 56, 56, 96)           384       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 56, 56, 96)           0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 56, 56, 16)           1536      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 56, 56, 16)           64        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 56, 56, 16)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 56, 56, 96)           1536      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 56, 56, 96)           384       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 56, 56, 96)           0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 57, 57, 96)           0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 28, 28, 96)           864       ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 28, 28, 96)           384       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 28, 28, 96)           0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 28, 28, 16)           1536      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 28, 28, 16)           64        ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 28, 28, 96)           1536      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 28, 28, 96)           384       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 28, 28, 96)           0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 28, 28, 96)           864       ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 28, 28, 96)           384       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 28, 28, 96)           0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 28, 28, 16)           1536      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 28, 28, 16)           64        ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 28, 28, 16)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 28, 28, 96)           1536      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 28, 28, 96)           384       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 28, 28, 96)           0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 28, 28, 96)           864       ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 28, 28, 96)           384       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 28, 28, 96)           0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 28, 28, 16)           1536      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 28, 28, 16)           64        ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 28, 28, 16)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 28, 28, 96)           1536      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 28, 28, 96)           384       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 28, 28, 96)           0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 29, 29, 96)           0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 14, 14, 96)           864       ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 14, 14, 96)           384       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 14, 14, 96)           0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 14, 14, 32)           3072      ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 14, 14, 32)           128       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 14, 14, 192)          6144      ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 14, 14, 192)          768       ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 14, 14, 192)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 14, 14, 192)          1728      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 14, 14, 192)          768       ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 14, 14, 192)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 14, 14, 32)           6144      ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 14, 14, 32)           128       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 14, 14, 32)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 14, 14, 192)          6144      ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 14, 14, 192)          768       ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 14, 14, 192)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 14, 14, 192)          1728      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 14, 14, 192)          768       ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 14, 14, 192)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 14, 14, 32)           6144      ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 14, 14, 32)           128       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 14, 14, 32)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 14, 14, 192)          6144      ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 14, 14, 192)          768       ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 14, 14, 192)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 14, 14, 192)          1728      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 14, 14, 192)          768       ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 14, 14, 192)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 14, 14, 32)           6144      ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 14, 14, 32)           128       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 14, 14, 32)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 14, 14, 192)          6144      ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 14, 14, 192)          768       ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 14, 14, 192)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 14, 14, 192)          1728      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 14, 14, 192)          768       ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 14, 14, 192)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 14, 14, 48)           9216      ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 14, 14, 48)           192       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 14, 14, 288)          13824     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 14, 14, 288)          1152      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 14, 14, 288)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 14, 14, 288)          2592      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 14, 14, 288)          1152      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 14, 14, 288)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 14, 14, 48)           13824     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 14, 14, 48)           192       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 14, 14, 48)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 14, 14, 288)          13824     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 14, 14, 288)          1152      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 14, 14, 288)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 14, 14, 288)          2592      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 14, 14, 288)          1152      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 14, 14, 288)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 14, 14, 48)           13824     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 14, 14, 48)           192       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 14, 14, 48)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 14, 14, 288)          13824     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 14, 14, 288)          1152      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 14, 14, 288)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 15, 15, 288)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 7, 7, 288)            2592      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 7, 7, 288)            1152      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 7, 7, 288)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 7, 7, 80)             23040     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 7, 7, 80)             320       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 7, 7, 480)            38400     ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 7, 7, 480)            1920      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 7, 7, 480)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 7, 7, 480)            4320      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 7, 7, 480)            1920      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 7, 7, 480)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 7, 7, 80)             38400     ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 7, 7, 80)             320       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 7, 7, 80)             0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 7, 7, 480)            38400     ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 7, 7, 480)            1920      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 7, 7, 480)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 7, 7, 480)            4320      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 7, 7, 480)            1920      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 7, 7, 480)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 7, 7, 80)             38400     ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 7, 7, 80)             320       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 7, 7, 80)             0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 7, 7, 480)            38400     ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 7, 7, 480)            1920      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 7, 7, 480)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 7, 7, 480)            4320      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 7, 7, 480)            1920      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 7, 7, 480)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 7, 7, 160)            76800     ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 7, 7, 160)            640       ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 7, 7, 1280)           204800    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 7, 7, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 7, 7, 1280)           0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1280)                 0         ['out_relu[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 102)                  130662    ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 836886 (3.19 MB)
# Trainable params: 130662 (510.40 KB)
# Non-trainable params: 706224 (2.69 MB)
# __________________________________________________________________________________________________

# %%
history = model.fit(
    train_gen,
    steps_per_epoch=num_train//batch_size,
    epochs=60,
    validation_data=val_gen,
    validation_steps=num_val//batch_size
)
# Out:
# Epoch 1/60
# 102/102 [==============================] - 127s 1s/step - loss: 2.9290 - accuracy: 0.3697 - val_loss: 1.6852 - val_accuracy: 0.6425
# Epoch 2/60
# 102/102 [==============================] - 118s 1s/step - loss: 1.3838 - accuracy: 0.6986 - val_loss: 1.0884 - val_accuracy: 0.7725
# Epoch 3/60
# 102/102 [==============================] - 121s 1s/step - loss: 1.0054 - accuracy: 0.7728 - val_loss: 0.8466 - val_accuracy: 0.8188
# Epoch 4/60
# 102/102 [==============================] - 123s 1s/step - loss: 0.8219 - accuracy: 0.8064 - val_loss: 0.7357 - val_accuracy: 0.8263
# Epoch 5/60
# 102/102 [==============================] - 120s 1s/step - loss: 0.7038 - accuracy: 0.8366 - val_loss: 0.6689 - val_accuracy: 0.8350
# Epoch 6/60
# 102/102 [==============================] - 123s 1s/step - loss: 0.6541 - accuracy: 0.8421 - val_loss: 0.6097 - val_accuracy: 0.8506
# Epoch 7/60
# 102/102 [==============================] - 121s 1s/step - loss: 0.5811 - accuracy: 0.8582 - val_loss: 0.5735 - val_accuracy: 0.8556
# Epoch 8/60
# 102/102 [==============================] - 120s 1s/step - loss: 0.5360 - accuracy: 0.8716 - val_loss: 0.5577 - val_accuracy: 0.8537
# Epoch 9/60
# 102/102 [==============================] - 123s 1s/step - loss: 0.4985 - accuracy: 0.8836 - val_loss: 0.5142 - val_accuracy: 0.8731
# Epoch 10/60
# 102/102 [==============================] - 121s 1s/step - loss: 0.4820 - accuracy: 0.8745 - val_loss: 0.5078 - val_accuracy: 0.8694
# Epoch 11/60
# 102/102 [==============================] - 120s 1s/step - loss: 0.4503 - accuracy: 0.8885 - val_loss: 0.4944 - val_accuracy: 0.8681
# Epoch 12/60
# 102/102 [==============================] - 122s 1s/step - loss: 0.4190 - accuracy: 0.8926 - val_loss: 0.4698 - val_accuracy: 0.8687
# Epoch 13/60
# 102/102 [==============================] - 119s 1s/step - loss: 0.4043 - accuracy: 0.8978 - val_loss: 0.4634 - val_accuracy: 0.8750
# Epoch 14/60
# 102/102 [==============================] - 121s 1s/step - loss: 0.3909 - accuracy: 0.9030 - val_loss: 0.4499 - val_accuracy: 0.8856
# Epoch 15/60
# 102/102 [==============================] - 117s 1s/step - loss: 0.3826 - accuracy: 0.9027 - val_loss: 0.4460 - val_accuracy: 0.8756
# Epoch 16/60
# 102/102 [==============================] - 121s 1s/step - loss: 0.3398 - accuracy: 0.9140 - val_loss: 0.4284 - val_accuracy: 0.8869
# Epoch 17/60
# 102/102 [==============================] - 124s 1s/step - loss: 0.3324 - accuracy: 0.9121 - val_loss: 0.4341 - val_accuracy: 0.8800
# Epoch 18/60
# 102/102 [==============================] - 122s 1s/step - loss: 0.3363 - accuracy: 0.9129 - val_loss: 0.4277 - val_accuracy: 0.8794
# Epoch 19/60
# 102/102 [==============================] - 120s 1s/step - loss: 0.3198 - accuracy: 0.9181 - val_loss: 0.4307 - val_accuracy: 0.8800
# Epoch 20/60
# 102/102 [==============================] - 122s 1s/step - loss: 0.2989 - accuracy: 0.9195 - val_loss: 0.4013 - val_accuracy: 0.8875
# Epoch 21/60
# 102/102 [==============================] - 122s 1s/step - loss: 0.3037 - accuracy: 0.9203 - val_loss: 0.4027 - val_accuracy: 0.8888
# Epoch 22/60
# 102/102 [==============================] - 120s 1s/step - loss: 0.2780 - accuracy: 0.9254 - val_loss: 0.4102 - val_accuracy: 0.8881
# Epoch 23/60
# 102/102 [==============================] - 120s 1s/step - loss: 0.2871 - accuracy: 0.9257 - val_loss: 0.4053 - val_accuracy: 0.8913
# Epoch 24/60
# 102/102 [==============================] - 121s 1s/step - loss: 0.2776 - accuracy: 0.9254 - val_loss: 0.3969 - val_accuracy: 0.8913
# Epoch 25/60
# 102/102 [==============================] - 118s 1s/step - loss: 0.2712 - accuracy: 0.9312 - val_loss: 0.4147 - val_accuracy: 0.8819
# Epoch 26/60
# 102/102 [==============================] - 120s 1s/step - loss: 0.2744 - accuracy: 0.9299 - val_loss: 0.3886 - val_accuracy: 0.8881
# Epoch 27/60
# 102/102 [==============================] - 123s 1s/step - loss: 0.2528 - accuracy: 0.9340 - val_loss: 0.4003 - val_accuracy: 0.8850
# Epoch 28/60
# 102/102 [==============================] - 117s 1s/step - loss: 0.2518 - accuracy: 0.9325 - val_loss: 0.3960 - val_accuracy: 0.8844
# Epoch 29/60
# 102/102 [==============================] - 121s 1s/step - loss: 0.2599 - accuracy: 0.9282 - val_loss: 0.3986 - val_accuracy: 0.8819
# Epoch 30/60
# 102/102 [==============================] - 116s 1s/step - loss: 0.2488 - accuracy: 0.9348 - val_loss: 0.3683 - val_accuracy: 0.8931
# Epoch 31/60
# 102/102 [==============================] - 115s 1s/step - loss: 0.2343 - accuracy: 0.9396 - val_loss: 0.3892 - val_accuracy: 0.8906
# Epoch 32/60
# 102/102 [==============================] - 119s 1s/step - loss: 0.2427 - accuracy: 0.9368 - val_loss: 0.3775 - val_accuracy: 0.8844
# Epoch 33/60
# 102/102 [==============================] - 116s 1s/step - loss: 0.2330 - accuracy: 0.9353 - val_loss: 0.3839 - val_accuracy: 0.8875
# Epoch 34/60
# 102/102 [==============================] - 119s 1s/step - loss: 0.2344 - accuracy: 0.9383 - val_loss: 0.3664 - val_accuracy: 0.8894
# Epoch 35/60
# 102/102 [==============================] - 117s 1s/step - loss: 0.2275 - accuracy: 0.9373 - val_loss: 0.4003 - val_accuracy: 0.8850
# Epoch 36/60
# 102/102 [==============================] - 114s 1s/step - loss: 0.2086 - accuracy: 0.9447 - val_loss: 0.3765 - val_accuracy: 0.8888
# Epoch 37/60
# 102/102 [==============================] - 117s 1s/step - loss: 0.2223 - accuracy: 0.9386 - val_loss: 0.3748 - val_accuracy: 0.8881
# Epoch 38/60
# 102/102 [==============================] - 119s 1s/step - loss: 0.2266 - accuracy: 0.9371 - val_loss: 0.3751 - val_accuracy: 0.8931
# Epoch 39/60
# 102/102 [==============================] - 120s 1s/step - loss: 0.2154 - accuracy: 0.9390 - val_loss: 0.3745 - val_accuracy: 0.8944
# Epoch 40/60
# 102/102 [==============================] - 116s 1s/step - loss: 0.2119 - accuracy: 0.9437 - val_loss: 0.3664 - val_accuracy: 0.8944
# Epoch 41/60
# 102/102 [==============================] - 118s 1s/step - loss: 0.2003 - accuracy: 0.9459 - val_loss: 0.3792 - val_accuracy: 0.8919
# Epoch 42/60
# 102/102 [==============================] - 117s 1s/step - loss: 0.2096 - accuracy: 0.9419 - val_loss: 0.3698 - val_accuracy: 0.8931
# Epoch 43/60
# 102/102 [==============================] - 120s 1s/step - loss: 0.2017 - accuracy: 0.9434 - val_loss: 0.3820 - val_accuracy: 0.8869
# Epoch 44/60
# 102/102 [==============================] - 116s 1s/step - loss: 0.1972 - accuracy: 0.9428 - val_loss: 0.3644 - val_accuracy: 0.8900
# Epoch 45/60
# 102/102 [==============================] - 117s 1s/step - loss: 0.1949 - accuracy: 0.9477 - val_loss: 0.3711 - val_accuracy: 0.8944
# Epoch 46/60
# 102/102 [==============================] - 117s 1s/step - loss: 0.1911 - accuracy: 0.9484 - val_loss: 0.3601 - val_accuracy: 0.8975
# Epoch 47/60
# 102/102 [==============================] - 116s 1s/step - loss: 0.1868 - accuracy: 0.9490 - val_loss: 0.3689 - val_accuracy: 0.8869
# Epoch 48/60
# 102/102 [==============================] - 120s 1s/step - loss: 0.1766 - accuracy: 0.9501 - val_loss: 0.3594 - val_accuracy: 0.8988
# Epoch 49/60
# 102/102 [==============================] - 120s 1s/step - loss: 0.1785 - accuracy: 0.9485 - val_loss: 0.3796 - val_accuracy: 0.8888
# Epoch 50/60
# 102/102 [==============================] - 120s 1s/step - loss: 0.1898 - accuracy: 0.9477 - val_loss: 0.3761 - val_accuracy: 0.8875
# Epoch 51/60
# 102/102 [==============================] - 115s 1s/step - loss: 0.1743 - accuracy: 0.9513 - val_loss: 0.3512 - val_accuracy: 0.8969
# Epoch 52/60
# 102/102 [==============================] - 117s 1s/step - loss: 0.1873 - accuracy: 0.9453 - val_loss: 0.3510 - val_accuracy: 0.8956
# Epoch 53/60
# 102/102 [==============================] - 118s 1s/step - loss: 0.1924 - accuracy: 0.9456 - val_loss: 0.3600 - val_accuracy: 0.8988
# Epoch 54/60
# 102/102 [==============================] - 118s 1s/step - loss: 0.1728 - accuracy: 0.9504 - val_loss: 0.3692 - val_accuracy: 0.8888
# Epoch 55/60
# 102/102 [==============================] - 116s 1s/step - loss: 0.1650 - accuracy: 0.9539 - val_loss: 0.3460 - val_accuracy: 0.8994
# Epoch 56/60
# 102/102 [==============================] - 117s 1s/step - loss: 0.1713 - accuracy: 0.9544 - val_loss: 0.3599 - val_accuracy: 0.9031
# Epoch 57/60
# 102/102 [==============================] - 116s 1s/step - loss: 0.1731 - accuracy: 0.9510 - val_loss: 0.3558 - val_accuracy: 0.8988
# Epoch 58/60
# 102/102 [==============================] - 118s 1s/step - loss: 0.1773 - accuracy: 0.9499 - val_loss: 0.3496 - val_accuracy: 0.9006
# Epoch 59/60
# 102/102 [==============================] - 116s 1s/step - loss: 0.1719 - accuracy: 0.9504 - val_loss: 0.3795 - val_accuracy: 0.8956
# Epoch 60/60
# 102/102 [==============================] - 119s 1s/step - loss: 0.1674 - accuracy: 0.9541 - val_loss: 0.3488 - val_accuracy: 0.9044

# %%
model.save('oxflower.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
